# %%
import apache_beam as beam
from beam_mysql.connector.io import ReadFromMySQL
from apache_beam import Pipeline
from datetime import datetime
import pytz
import os
from dotenv import load_dotenv

# %%
"""
Objetivo:

Construir un pipeline de procesamiento de datos que permita la ingestión de datos de una instancia SQL , su transformación conforme a los requisitos especificados y, finalmente, su carga en la misma instancia SQL.

Requisitos:

    Imputar valores faltantes de forma coherente con el contexto de los datos.

    Almacenar la fecha de la orden (fec_FechaOrden) en formato UTC-6.

    Agrupar los datos por sec_OrdenCommerce para reducir la dimensionalidad y generar nuevas columnas:

        Calcular el importe total de cada orden y almacenar el resultado en la columna imp_TotalOrden.

        Calcular el total de productos por orden a partir de la suma de num_Cantidad  y almacenar el resultado en la columna total_ProdsOrden.

        Agrupar las columnas des_Area, des_Categoria, des_Subcategoria  en un formato adecuado (arrays, JSON, JSON array, etc.) para facilitar su consulta y análisis.

Consideraciones Técnicas:

    Utilizar  Apache Beam SDK (Java o Python) para la construcción del pipeline.

    Cargar los datos del archivo CSV disponible aquí en tu instancia local SQL (SQL Server, PostgreSQL o MongoDB) para que la ingesta de tu pipeline suceda desde ese origen.

    El destino de los datos deberá ser un asset nuevo en la instancia SQL que hayas elegido. Se considerarán puntos extras si escribes la salida de datos a BigQuery.
."""
# Out:
# '\nObjetivo:\n\nConstruir un pipeline de procesamiento de datos que permita la ingestión de datos de una instancia SQL , su transformación conforme a los requisitos especificados y, finalmente, su carga en la misma instancia SQL.\n\nRequisitos:\n\n    Imputar valores faltantes de forma coherente con el contexto de los datos.\n\n    Almacenar la fecha de la orden (fec_FechaOrden) en formato UTC-6.\n\n    Agrupar los datos por sec_OrdenCommerce para reducir la dimensionalidad y generar nuevas columnas:\n\n        Calcular el importe total de cada orden y almacenar el resultado en la columna imp_TotalOrden.\n\n        Calcular el total de productos por orden a partir de la suma de num_Cantidad  y almacenar el resultado en la columna total_ProdsOrden.\n\n        Agrupar las columnas des_Area, des_Categoria, des_Subcategoria  en un formato adecuado (arrays, JSON, JSON array, etc.) para facilitar su consulta y análisis.\n\nConsideraciones Técnicas:\n\n    Utilizar  Apache Beam SDK (Java o Python) para la construcción del pipeline.\n\n    Cargar los datos del archivo CSV disponible aquí en tu instancia local SQL (SQL Server, PostgreSQL o MongoDB) para que la ingesta de tu pipeline suceda desde ese origen.\n\n    El destino de los datos deberá ser un asset nuevo en la instancia SQL que hayas elegido. Se considerarán puntos extras si escribes la salida de datos a BigQuery.\n.'

# %%
load_dotenv()
# Out:
# True

# %%
host = os.getenv('endpoint')
port = os.getenv('port')
db= os.getenv('db')
user = os.getenv('user_db')
password = os.getenv('pass_db')

# %%
errors=[]

# %%
def convert_to_utc_minus_6(row):
   
    try:
        local_datetime = row['fec_FechaOrden']
    
   
        local_datetime = local_datetime.replace(tzinfo=pytz.UTC)
        utc_minus_6_datetime = local_datetime.astimezone(pytz.timezone('America/Mexico_City'))
    
        row['fec_FechaOrden'] = utc_minus_6_datetime
        return row
    except Exception as e:
        errors.append(e)

# %%
def run():
    with Pipeline() as pipeline:
        rows = (
            pipeline
            | 'LeerDesdeMySQL' >> ReadFromMySQL(
                query="SELECT * FROM test;",
                host=host,
                database=db,
                user=user,
                password=password,
                port=port
            )
            | 'Convertir a UTC-6' >> beam.Map(convert_to_utc_minus_6)
            | 'MostrarDatos2' >> beam.Map(print) 
        )

# %%
run()
# Out:
# INFO:beam_mysql.connector.client:Successfully execute query: EXPLAIN SELECT * FROM (SELECT * FROM test) as subq
# INFO:beam_mysql.connector.client:Successfully execute query: SELECT * FROM test
# {'idu_ArticuloCodigo': 507202, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Bebés', 'des_Subcategoria': 'Bebés', 'num_Cantidad': 1, 'sec_Orden': 1195043, 'sec_OrdenCommerce': 4484389, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 33, 46, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1809.48, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 526223, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Bebés', 'des_Subcategoria': 'Bebés', 'num_Cantidad': 1, 'sec_Orden': 1195097, 'sec_OrdenCommerce': 4484817, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 53, 4, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2262.93, 'imp_DescuentoPromocion': 753.45}
# {'idu_ArticuloCodigo': 526541, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Bebés', 'des_Subcategoria': 'Bebés', 'num_Cantidad': 1, 'sec_Orden': 1195267, 'sec_OrdenCommerce': 4486351, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 26, 3, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30020.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2930.17, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 526541, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Bebés', 'des_Subcategoria': 'Bebés', 'num_Cantidad': 1, 'sec_Orden': 1195263, 'sec_OrdenCommerce': 4486338, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 23, 12, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2930.17, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 347949, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Camas', 'num_Cantidad': 1, 'sec_Orden': 1195075, 'sec_OrdenCommerce': 4484742, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 15, 39, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30013.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1723.28, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 446726, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1193665, 'sec_OrdenCommerce': 4471730, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 41, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4740.52, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 486043, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1193468, 'sec_OrdenCommerce': 4467660, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 10, 19, 2, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30017.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 7326.72, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 486043, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1195151, 'sec_OrdenCommerce': 4485364, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 26, 53, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 7326.72, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 343137, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Terraza y Jardín', 'des_Subcategoria': 'Muebles de Jardín', 'num_Cantidad': 1, 'sec_Orden': 1195346, 'sec_OrdenCommerce': 4487075, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 43, 36, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1378.45, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 456641, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Decoración', 'des_Subcategoria': 'Decoración', 'num_Cantidad': 1, 'sec_Orden': 1195378, 'sec_OrdenCommerce': 4487291, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 22, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.45, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 469157, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Decoración', 'des_Subcategoria': 'Decoración', 'num_Cantidad': 1, 'sec_Orden': 1195378, 'sec_OrdenCommerce': 4487291, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 22, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.45, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 469173, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Decoración', 'des_Subcategoria': 'Decoración', 'num_Cantidad': 4, 'sec_Orden': 1195384, 'sec_OrdenCommerce': 4487353, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 36, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.45, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 483575, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Decoración', 'des_Subcategoria': 'Decoración', 'num_Cantidad': 1, 'sec_Orden': 1195378, 'sec_OrdenCommerce': 4487291, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 22, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.45, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 310085, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1195243, 'sec_OrdenCommerce': 4484636, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 54, 21, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2757.76, 'imp_DescuentoPromocion': 517.24}
# {'idu_ArticuloCodigo': 311804, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1194962, 'sec_OrdenCommerce': 4483487, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 17, 16, 10, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3361.21, 'imp_DescuentoPromocion': 517.24}
# {'idu_ArticuloCodigo': 339751, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1194968, 'sec_OrdenCommerce': 4483573, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 17, 51, 34, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1809.48, 'imp_DescuentoPromocion': 258.62}
# {'idu_ArticuloCodigo': 343919, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1195129, 'sec_OrdenCommerce': 4485197, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 8, 51, 48, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2499.14, 'imp_DescuentoPromocion': 431.03}
# {'idu_ArticuloCodigo': 345636, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 2, 'sec_Orden': 1193736, 'sec_OrdenCommerce': 4472442, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 16, 1, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1119.83, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 346861, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1194987, 'sec_OrdenCommerce': 4483824, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 21, 5, 13, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30003.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3878.45, 'imp_DescuentoPromocion': 258.62}
# {'idu_ArticuloCodigo': 308331, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1195003, 'sec_OrdenCommerce': 4483649, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 3, 17, 25, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1895.69, 'imp_DescuentoPromocion': 344.83}
# {'idu_ArticuloCodigo': 311642, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1195251, 'sec_OrdenCommerce': 4486259, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 8, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2240.51, 'imp_DescuentoPromocion': 344.83}
# {'idu_ArticuloCodigo': 313033, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1195393, 'sec_OrdenCommerce': 4487476, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 42, 15, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2068.11, 'imp_DescuentoPromocion': 431.03}
# {'idu_ArticuloCodigo': 314111, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1194965, 'sec_OrdenCommerce': 4483522, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 17, 26, 18, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1723.28, 'imp_DescuentoPromocion': 258.62}
# {'idu_ArticuloCodigo': 617245, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1195156, 'sec_OrdenCommerce': 4485419, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 38, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30007.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 5171.55, 'imp_DescuentoPromocion': 603.45}
# {'idu_ArticuloCodigo': 617407, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1193685, 'sec_OrdenCommerce': 4472085, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 15, 2, 25, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3016.38, 'imp_DescuentoPromocion': 1982.76}
# {'idu_ArticuloCodigo': 617407, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1193457, 'sec_OrdenCommerce': 4469832, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 10, 10, 59, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30010.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3016.38, 'imp_DescuentoPromocion': 1982.76}
# {'idu_ArticuloCodigo': 562637, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Automotriz', 'des_Subcategoria': 'Automotriz', 'num_Cantidad': 1, 'sec_Orden': 1195092, 'sec_OrdenCommerce': 4484476, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 44, 29, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30030.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 861.21, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 562637, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Automotriz', 'des_Subcategoria': 'Automotriz', 'num_Cantidad': 2, 'sec_Orden': 1195208, 'sec_OrdenCommerce': 4485862, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 59, 21, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 861.21, 'imp_DescuentoPromocion': 344.82}
# {'idu_ArticuloCodigo': 227701, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio', 'num_Cantidad': 1, 'sec_Orden': 1194988, 'sec_OrdenCommerce': 4483835, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 21, 16, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 947.42, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 228439, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio', 'num_Cantidad': 1, 'sec_Orden': 1195049, 'sec_OrdenCommerce': 4484420, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 47, 6, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2412.93, 'imp_DescuentoPromocion': 5086.21}
# {'idu_ArticuloCodigo': 228439, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio', 'num_Cantidad': 1, 'sec_Orden': 1195167, 'sec_OrdenCommerce': 4485535, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 47, 36, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30010.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2412.93, 'imp_DescuentoPromocion': 5086.21}
# {'idu_ArticuloCodigo': 268937, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio', 'num_Cantidad': 1, 'sec_Orden': 1195399, 'sec_OrdenCommerce': 4487573, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 55, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30022.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1033.62, 'imp_DescuentoPromocion': 86.21}
# {'idu_ArticuloCodigo': 481327, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Decoración', 'des_Subcategoria': 'Decoración', 'num_Cantidad': 1, 'sec_Orden': 1195351, 'sec_OrdenCommerce': 4486931, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 50, 31, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30001.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 464.65, 'imp_DescuentoPromocion': 568.97}
# {'idu_ArticuloCodigo': 342483, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1195085, 'sec_OrdenCommerce': 4484701, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 32, 30, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30015.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3102.59, 'imp_DescuentoPromocion': 517.24}
# {'idu_ArticuloCodigo': 342505, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Muebles para Recamara', 'num_Cantidad': 1, 'sec_Orden': 1195287, 'sec_OrdenCommerce': 4486511, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 56, 58, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3964.65, 'imp_DescuentoPromocion': 689.66}
# None
# {'idu_ArticuloCodigo': 255861, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': '"Cómputo', 'des_Subcategoria': ' Tablets y Videojuegos"', 'num_Cantidad': 0, 'sec_Orden': 2, 'sec_OrdenCommerce': 1195311, 'fec_FechaOrden': datetime.datetime(2036, 6, 5, 19, 0, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 2018.0, 'flag_Promocion': 127, 'imp_PrecioContadoUnitario': 0.0, 'imp_DescuentoPromocion': 1206.04}
# None
# {'idu_ArticuloCodigo': 703972, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Lencería', 'des_Subcategoria': 'Lencería', 'num_Cantidad': 1, 'sec_Orden': 1195237, 'sec_OrdenCommerce': 4484808, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 43, 43, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 25.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 727705, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Lencería', 'des_Subcategoria': 'Lencería', 'num_Cantidad': 1, 'sec_Orden': 1195282, 'sec_OrdenCommerce': 4485985, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 47, 19, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 82.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 758699, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Lencería', 'des_Subcategoria': 'Lencería', 'num_Cantidad': 1, 'sec_Orden': 1195000, 'sec_OrdenCommerce': 4483957, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 2, 57, 5, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 77.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 761905, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Lencería', 'des_Subcategoria': 'Lencería', 'num_Cantidad': 1, 'sec_Orden': 1195236, 'sec_OrdenCommerce': 3604469, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 36, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 85.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 769300, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Lencería', 'des_Subcategoria': 'Lencería', 'num_Cantidad': 1, 'sec_Orden': 1195000, 'sec_OrdenCommerce': 4483957, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 2, 57, 5, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 103.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 617351, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1195358, 'sec_OrdenCommerce': 4487207, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 59, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30030.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1119.83, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 617873, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1195372, 'sec_OrdenCommerce': 4486507, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 13, 29, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3275.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 623342, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1193740, 'sec_OrdenCommerce': 4472331, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 16, 6, 2, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30020.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2068.11, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 623407, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Cocción', 'num_Cantidad': 1, 'sec_Orden': 1195205, 'sec_OrdenCommerce': 4485624, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 50, 22, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1637.07, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 513059, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Deportes Y Actividades Al Aire', 'des_Subcategoria': 'Outdoor', 'num_Cantidad': 1, 'sec_Orden': 1195149, 'sec_OrdenCommerce': 4485412, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 22, 19, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 214.66, 'imp_DescuentoPromocion': 43.1}
# {'idu_ArticuloCodigo': 533491, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Deportes Y Actividades Al Aire', 'des_Subcategoria': 'Outdoor', 'num_Cantidad': 1, 'sec_Orden': 1195045, 'sec_OrdenCommerce': 4484377, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 36, 33, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30010.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 145.69, 'imp_DescuentoPromocion': 25.86}
# {'idu_ArticuloCodigo': 144687, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Caballero Exterior', 'des_Subcategoria': 'Caballero Exterior', 'num_Cantidad': 1, 'sec_Orden': 1194953, 'sec_OrdenCommerce': 4483361, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 16, 25, 53, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 344.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 162797, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Caballero Exterior', 'des_Subcategoria': 'Caballero Exterior', 'num_Cantidad': 1, 'sec_Orden': 1195113, 'sec_OrdenCommerce': 4475924, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 8, 11, 45, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 387.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 163155, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Caballero Exterior', 'des_Subcategoria': 'Caballero Exterior', 'num_Cantidad': 1, 'sec_Orden': 1194953, 'sec_OrdenCommerce': 4483361, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 16, 25, 53, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 482.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 508501, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195345, 'sec_OrdenCommerce': 4486831, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 42, 33, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30017.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1550.86, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 528692, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195401, 'sec_OrdenCommerce': 4487437, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 55, 50, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 731.89, 'imp_DescuentoPromocion': 86.21}
# {'idu_ArticuloCodigo': 529281, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195055, 'sec_OrdenCommerce': 4407935, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 6, 5, 30, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1723.28, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 538191, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195356, 'sec_OrdenCommerce': 4486912, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 58, 2, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30022.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1357.76, 'imp_DescuentoPromocion': 451.72}
# {'idu_ArticuloCodigo': 136761, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195144, 'sec_OrdenCommerce': 4485339, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 15, 27, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30018.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 835.34, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 137871, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195350, 'sec_OrdenCommerce': 4486641, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 49, 38, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30006.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 188.79, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 138444, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1193715, 'sec_OrdenCommerce': 4472289, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 15, 41, 12, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 731.9, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 408107, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Blancos', 'num_Cantidad': 1, 'sec_Orden': 1195378, 'sec_OrdenCommerce': 4487291, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 22, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30002.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 171.55, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 231113, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio Personal', 'num_Cantidad': 1, 'sec_Orden': 1194948, 'sec_OrdenCommerce': 4483372, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 16, 14, 59, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 102.59, 'imp_DescuentoPromocion': 25.86}
# {'idu_ArticuloCodigo': 231113, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio Personal', 'num_Cantidad': 1, 'sec_Orden': 1195141, 'sec_OrdenCommerce': 4485234, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 6, 20, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 96.55, 'imp_DescuentoPromocion': 31.9}
# {'idu_ArticuloCodigo': 115517, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 2, 'sec_Orden': 1195140, 'sec_OrdenCommerce': 4481711, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 6, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 602.59, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 215584, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Audio Personal', 'num_Cantidad': 1, 'sec_Orden': 1195109, 'sec_OrdenCommerce': 4484991, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 8, 5, 12, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 697.41, 'imp_DescuentoPromocion': 465.52}
# {'idu_ArticuloCodigo': 345768, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Comedor', 'num_Cantidad': 1, 'sec_Orden': 1193660, 'sec_OrdenCommerce': 4471626, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 34, 24, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30003.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 8619.83, 'imp_DescuentoPromocion': 431.03}
# {'idu_ArticuloCodigo': 348422, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Comedor', 'num_Cantidad': 1, 'sec_Orden': 1195157, 'sec_OrdenCommerce': 4485375, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 38, 50, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30018.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4912.93, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 153850, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Caballero Exterior', 'des_Subcategoria': 'Caballero Exterior', 'num_Cantidad': 1, 'sec_Orden': 1194995, 'sec_OrdenCommerce': 4483943, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 1, 37, 10, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 215.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 310608, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Deportivo', 'des_Subcategoria': 'Deportivo', 'num_Cantidad': 1, 'sec_Orden': 1195236, 'sec_OrdenCommerce': 3604469, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 36, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 137.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 313308, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Deportivo', 'des_Subcategoria': 'Deportivo', 'num_Cantidad': 1, 'sec_Orden': 1195236, 'sec_OrdenCommerce': 3604469, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 36, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 258.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 313649, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Deportivo', 'des_Subcategoria': 'Deportivo', 'num_Cantidad': 1, 'sec_Orden': 1195236, 'sec_OrdenCommerce': 3604469, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 36, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 373007, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Deportivo', 'des_Subcategoria': 'Deportivo', 'num_Cantidad': 1, 'sec_Orden': 1195236, 'sec_OrdenCommerce': 3604469, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 36, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 85.0, 'imp_DescuentoPromocion': 0.0}
# None
# {'idu_ArticuloCodigo': 342998, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1195115, 'sec_OrdenCommerce': 4485056, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 8, 18, 55, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30020.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 9654.31, 'imp_DescuentoPromocion': 1896.55}
# {'idu_ArticuloCodigo': 345148, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Colchones y Blancos', 'des_Subcategoria': 'Colchones', 'num_Cantidad': 1, 'sec_Orden': 1195392, 'sec_OrdenCommerce': 4487436, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 41, 58, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30020.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 3102.58, 'imp_DescuentoPromocion': 603.45}
# {'idu_ArticuloCodigo': 608531, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1195194, 'sec_OrdenCommerce': 4485774, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 33, 22, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4223.28, 'imp_DescuentoPromocion': 258.62}
# {'idu_ArticuloCodigo': 617148, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1195019, 'sec_OrdenCommerce': 4484189, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 4, 39, 9, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4740.52, 'imp_DescuentoPromocion': 2155.17}
# {'idu_ArticuloCodigo': 617148, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1193481, 'sec_OrdenCommerce': 4470171, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 10, 49, 11, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4740.52, 'imp_DescuentoPromocion': 2155.17}
# {'idu_ArticuloCodigo': 619876, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1193568, 'sec_OrdenCommerce': 4471043, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 12, 25, 18, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30030.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 6637.07, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 621935, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1195230, 'sec_OrdenCommerce': 4486069, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 32, 51, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 7757.76, 'imp_DescuentoPromocion': 2586.21}
# {'idu_ArticuloCodigo': 623351, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Línea Blanca', 'des_Subcategoria': 'Refrigeración', 'num_Cantidad': 1, 'sec_Orden': 1193690, 'sec_OrdenCommerce': 4471895, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 15, 6, 2, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 6292.24, 'imp_DescuentoPromocion': 2155.17}
# {'idu_ArticuloCodigo': 307815, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Comedor', 'num_Cantidad': 1, 'sec_Orden': 1195212, 'sec_OrdenCommerce': 4485905, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 5, 3, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 947.41, 'imp_DescuentoPromocion': 0.0}
# None
# None
# {'idu_ArticuloCodigo': 118867, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195000, 'sec_OrdenCommerce': 4483957, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 2, 57, 5, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 103.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 118872, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195286, 'sec_OrdenCommerce': 4486260, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 54, 40, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 111.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 126452, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195158, 'sec_OrdenCommerce': 4485447, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 39, 26, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 146.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 135842, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195204, 'sec_OrdenCommerce': 4485784, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 49, 20, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 137.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 136072, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195000, 'sec_OrdenCommerce': 4483957, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 2, 57, 5, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': -40.0, 'imp_DescuentoPromocion': 134.0}
# {'idu_ArticuloCodigo': 156532, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195204, 'sec_OrdenCommerce': 4485784, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 49, 20, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 165847, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Interior y Calceteria', 'des_Subcategoria': 'Interior y Calceteria', 'num_Cantidad': 1, 'sec_Orden': 1195204, 'sec_OrdenCommerce': 4485784, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 49, 20, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 109071, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195042, 'sec_OrdenCommerce': 4484390, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 32, 32, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30018.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 947.41, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 136361, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195140, 'sec_OrdenCommerce': 4481711, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 6, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 559.49, 'imp_DescuentoPromocion': 60.34}
# None
# None
# None
# {'idu_ArticuloCodigo': 487643, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1195331, 'sec_OrdenCommerce': 4486956, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 15, 21, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30017.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4050.86, 'imp_DescuentoPromocion': 258.62}
# {'idu_ArticuloCodigo': 489476, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1194974, 'sec_OrdenCommerce': 4483631, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 18, 39, 45, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30017.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 4050.87, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 917877, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Óptica', 'des_Subcategoria': 'Lente solar', 'num_Cantidad': 1, 'sec_Orden': 1195041, 'sec_OrdenCommerce': 4484364, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 32, 19, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30014.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 421.55, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 918377, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Óptica', 'des_Subcategoria': 'Lente solar', 'num_Cantidad': 1, 'sec_Orden': 1195400, 'sec_OrdenCommerce': 4487365, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 55, 47, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 2412.93, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 469386, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Muebles de Hogar y Recamara', 'des_Subcategoria': 'Salas', 'num_Cantidad': 1, 'sec_Orden': 1193669, 'sec_OrdenCommerce': 4471945, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 46, 10, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30003.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1895.69, 'imp_DescuentoPromocion': 172.41}
# {'idu_ArticuloCodigo': 313950, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Dama Joven', 'des_Subcategoria': 'Dama Joven', 'num_Cantidad': 1, 'sec_Orden': 1195105, 'sec_OrdenCommerce': 4203995, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 59, 45, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 156.0, 'imp_DescuentoPromocion': 171.0}
# {'idu_ArticuloCodigo': 277219, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Car Audio', 'num_Cantidad': 1, 'sec_Orden': 1195403, 'sec_OrdenCommerce': 4487575, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 58, 40, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30011.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1878.45, 'imp_DescuentoPromocion': 620.69}
# {'idu_ArticuloCodigo': 280661, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Car Audio', 'num_Cantidad': 1, 'sec_Orden': 1195189, 'sec_OrdenCommerce': 4485720, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 26, 13, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30018.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 861.21, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 116441, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Maletas', 'des_Subcategoria': 'Artículos de Oficina', 'num_Cantidad': 1, 'sec_Orden': 1195020, 'sec_OrdenCommerce': 4484028, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 4, 39, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30020.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 33.62, 'imp_DescuentoPromocion': 0.0}
# None
# None
# None
# None
# None
# None
# None
# {'idu_ArticuloCodigo': 203683, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Video', 'num_Cantidad': 1, 'sec_Orden': 1195280, 'sec_OrdenCommerce': 4486460, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 12, 46, 11, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 257.76, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 225677, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Audio y Video', 'des_Subcategoria': 'Video', 'num_Cantidad': 1, 'sec_Orden': 1195365, 'sec_OrdenCommerce': 4487240, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 7, 45, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30004.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 904.31, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 502936, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Bebés', 'des_Subcategoria': 'Bebés', 'num_Cantidad': 1, 'sec_Orden': 1195293, 'sec_OrdenCommerce': 4486555, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 13, 9, 30, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 128.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 116191, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195173, 'sec_OrdenCommerce': 4485515, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 59, 3, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 516.38, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 133051, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195173, 'sec_OrdenCommerce': 4485515, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 9, 59, 3, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 990.52, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 313035, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Dama Joven', 'des_Subcategoria': 'Dama Joven', 'num_Cantidad': 1, 'sec_Orden': 1195087, 'sec_OrdenCommerce': 4484809, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 34, 31, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 111.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 148762, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Caballero Exterior', 'des_Subcategoria': 'Caballero Exterior', 'num_Cantidad': 1, 'sec_Orden': 1193753, 'sec_OrdenCommerce': 4452116, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 16, 29, 43, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 534.0, 'imp_DescuentoPromocion': 0.0}
# ...
# {'idu_ArticuloCodigo': 739350, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195082, 'sec_OrdenCommerce': 4484621, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 27, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 241.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 755422, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1194993, 'sec_OrdenCommerce': 4483902, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 23, 20, 27, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 68.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 761272, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195095, 'sec_OrdenCommerce': 4484829, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 49, 15, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 206.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 781638, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195125, 'sec_OrdenCommerce': 4485181, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 8, 44, 12, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 258.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 700330, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1193661, 'sec_OrdenCommerce': 4471723, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 36, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 491.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 701130, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1193661, 'sec_OrdenCommerce': 4471723, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 36, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 701130, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1193661, 'sec_OrdenCommerce': 4471723, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 36, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 702443, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195329, 'sec_OrdenCommerce': 4486872, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 11, 22, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 172.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 702495, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195198, 'sec_OrdenCommerce': 4485800, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 39, 40, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 68.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 702783, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195224, 'sec_OrdenCommerce': 4457064, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 11, 24, 5, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 702904, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195401, 'sec_OrdenCommerce': 4487437, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 55, 50, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 370.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 703139, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195294, 'sec_OrdenCommerce': 4486584, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 13, 9, 32, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 85.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 703225, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1194993, 'sec_OrdenCommerce': 4483902, 'fec_FechaOrden': datetime.datetime(2017, 12, 31, 23, 20, 27, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 77.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 703280, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195074, 'sec_OrdenCommerce': 4484674, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 13, 3, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 111.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 703303, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195026, 'sec_OrdenCommerce': 4446452, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 4, 55, 23, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 146.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 703356, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195062, 'sec_OrdenCommerce': 4484656, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 6, 47, 17, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 344.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 704876, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195200, 'sec_OrdenCommerce': 4485822, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 10, 41, 36, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 689.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 705136, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195072, 'sec_OrdenCommerce': 4484760, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 11, 11, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 309.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 726199, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1193710, 'sec_OrdenCommerce': 4463235, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 15, 39, 16, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 85.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 737372, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195053, 'sec_OrdenCommerce': 4484454, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 53, 51, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 172.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 737394, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195089, 'sec_OrdenCommerce': 4484175, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 36, 33, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 163.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 760322, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195089, 'sec_OrdenCommerce': 4484175, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 36, 33, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 154.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 761238, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1193661, 'sec_OrdenCommerce': 4471723, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 14, 36, 35, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 508.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 770199, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195294, 'sec_OrdenCommerce': 4486584, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 13, 9, 32, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 163.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 770216, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195058, 'sec_OrdenCommerce': 4484511, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 6, 15, 24, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 180.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 770216, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195091, 'sec_OrdenCommerce': 4484844, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 40, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 180.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 775338, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195095, 'sec_OrdenCommerce': 4484829, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 49, 15, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 327.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 793233, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Juguetes', 'des_Subcategoria': 'Juguetes', 'num_Cantidad': 1, 'sec_Orden': 1195329, 'sec_OrdenCommerce': 4486872, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 11, 22, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 249.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 807836, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Zapato Infantil', 'des_Subcategoria': 'Zapato Infantil', 'num_Cantidad': 1, 'sec_Orden': 1195371, 'sec_OrdenCommerce': 4487210, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 15, 11, 27, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 430.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 807828, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Zapato Infantil', 'des_Subcategoria': 'Zapato Infantil', 'num_Cantidad': 1, 'sec_Orden': 1195091, 'sec_OrdenCommerce': 4484844, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 40, 1, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 516.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 873827, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Zapato Infantil', 'des_Subcategoria': 'Zapato Infantil', 'num_Cantidad': 1, 'sec_Orden': 1193438, 'sec_OrdenCommerce': 4469934, 'fec_FechaOrden': datetime.datetime(2017, 12, 29, 9, 51, 59, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 275.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 808163, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Zapato Infantil', 'des_Subcategoria': 'Zapato Infantil', 'num_Cantidad': 1, 'sec_Orden': 1195330, 'sec_OrdenCommerce': 4486878, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 12, 18, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 215.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 808512, 'flag_Estatus': 1, 'des_Area': 'Ropa', 'des_Categoria': 'Zapato Infantil', 'des_Subcategoria': 'Zapato Infantil', 'num_Cantidad': 1, 'sec_Orden': 1195330, 'sec_OrdenCommerce': 4486878, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 14, 12, 18, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 0.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 241.0, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 107816, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 1, 'sec_Orden': 1195047, 'sec_OrdenCommerce': 4484355, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 5, 44, 28, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30016.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 1102.59, 'imp_DescuentoPromocion': 0.0}
# {'idu_ArticuloCodigo': 119458, 'flag_Estatus': 1, 'des_Area': 'Muebles', 'des_Categoria': 'Enseres Domésticos', 'des_Subcategoria': 'Electrodomésticos', 'num_Cantidad': 3, 'sec_Orden': 1195081, 'sec_OrdenCommerce': 4484853, 'fec_FechaOrden': datetime.datetime(2018, 1, 1, 7, 27, 22, tzinfo=<DstTzInfo 'America/Mexico_City' CST-1 day, 18:00:00 STD>), 'idu_BodegaCodigo': 30001.0, 'flag_Promocion': 0, 'imp_PrecioContadoUnitario': 439.65, 'imp_DescuentoPromocion': 437.07}
